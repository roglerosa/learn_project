# %%
需要出一个中石油订单的分析报告。

首先获取名单明细数据，参考项目6-目标数据，使用belong_manu这个字段。

然后制作报告，参考项目6-目标报告
# Out:
#   Cell In[2], line 1
#     需要出一个中石油订单的分析报告。
#                    ^
# SyntaxError: invalid character '。' (U+3002)
