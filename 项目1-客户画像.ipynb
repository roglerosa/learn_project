# %% [markdown]
# 仿照项目1-参考文件，根据源文件：江苏K8003客户.xlsx，读取数据，构建一个客户画像分析函数，并执行该函数。

# %% [markdown]
# 要求输出的文本如下：
#
# ==================================================
# 客户画像分析
# ==================================================
#
# 【整体分析】
# 一共903家客户
#
# 从公司规模来看：
#   大客户52家，占比5.8%
#   中客户119家，占比13.2%
#   小客户732家，占比81.1%
#
# 从授信区间来看：
#   未授信客户726家，占比80.4%
#   1-7天客户128家，占比14.2%
#   8-15天客户29家，占比3.2%
#   16-30天客户20家，占比2.2%
#
# 从20年复购率来看：
#   月月购客户23家，占比2.5%
#   二月购客户39家，占比4.3%
#   三月购客户27家，占比3.0%
#   四月购客户14家，占比1.6%
#   半年购客户29家，占比3.2%
#   年购客户57家，占比6.3%
#
# ==================================================
# 客户分大中小）
# ==================================================
#
# 【大客户分析】
# 大客户一共52家
# 从授信区间来看：
#   未授信客户28家，占比53.8%
#   1-7天客户13家，占比25.0%
#   8-15天客户6家，占比11.5%
#   16-30天客户5家，占比9.6%
# 从20年复购率来看：
#   月月购客户1家，占比1.9%
#   二月购客户7家，占比13.5%
#   三月购客户1家，占比1.9%
#   四月购客户3家，占比5.8%
#   半年购客户2家，占比3.8%
#   年购客户6家，占比11.5%
#
# 【中客户分析】
# 中客户一共119家
# 从授信区间来看：
#   未授信客户56家，占比47.1%
#   1-7天客户44家，占比37.0%
#   8-15天客户12家，占比10.1%
#   16-30天客户7家，占比5.9%
# 从20年复购率来看：
#   月月购客户5家，占比4.2%
#   二月购客户10家，占比8.4%
#   三月购客户6家，占比5.0%
#   四月购客户2家，占比1.7%
#   半年购客户6家，占比5.0%
#   年购客户12家，占比10.1%
#
# 【小客户分析】
# 小客户一共732家
# 从授信区间来看：
#   未授信客户642家，占比87.7%
#   1-7天客户71家，占比9.7%
#   8-15天客户11家，占比1.5%
#   16-30天客户8家，占比1.1%
# 从20年复购率来看：
#   月月购客户17家，占比2.3%
#   二月购客户22家，占比3.0%
#   三月购客户20家，占比2.7%
#   四月购客户9家，占比1.2%
#   半年购客户21家，占比2.9%
#   年购客户39家，占比5.3%
